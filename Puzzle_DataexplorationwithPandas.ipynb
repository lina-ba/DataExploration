# %% [markdown]
# <a href="https://colab.research.google.com/github/lina-ba/preprocessing/blob/main/Puzzle_DataexplorationwithPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data cleaning

# %%
import pandas as pd

# %%
df=pd.read_csv("Historical_data_of_Tanzania_Tourism.csv")
df.head(2)
# Out:
#         ID         country age_group        travel_with  total_female  \
# 0   tour_0      SWIZERLAND     45-64  Friends/Relatives           1.0
# 1  tour_10  UNITED KINGDOM     25-44                NaN           1.0
#
#    total_male               purpose     main_activity         info_source  \
# 0         1.0  Leisure and Holidays  Wildlife tourism  Friends, relatives
# 1         0.0  Leisure and Holidays  Cultural tourism              others
#
#   tour_arrangement  ... package_transport_tz package_sightseeing  \
# 0      Independent  ...                   No                  No
# 1      Independent  ...                   No                  No
#
#   package_guided_tour package_insurance night_mainland night_zanzibar  \
# 0                  No                No           13.0            0.0
# 1                  No                No           14.0            7.0
#
#   payment_mode  first_trip_tz                       most_impressing total_cost
# ...

# %%
df.shape
# Out:
# (4809, 23)

# %%
df.columns
# Out:
# Index(['ID', 'country', 'age_group', 'travel_with', 'total_female',
#        'total_male', 'purpose', 'main_activity', 'info_source',
#        'tour_arrangement', 'package_transport_int', 'package_accomodation',
#        'package_food', 'package_transport_tz', 'package_sightseeing',
#        'package_guided_tour', 'package_insurance', 'night_mainland',
#        'night_zanzibar', 'payment_mode', 'first_trip_tz', 'most_impressing',
#        'total_cost'],
#       dtype='object')

# %% [markdown]
# Identify the columns containing missing values

# %%
# df[df.isnull()==True].columns #not correct #It returns all column names, regardless of whether they contain missing values or not.
#So  the filtering step is not meaningful or helpful in the one above.
df.columns[df.isnull().any()]
#tis one returns the columns that contain at least one NaN
# Out:
# Index(['travel_with', 'total_female', 'total_male', 'most_impressing'], dtype='object')

# %% [markdown]
# Apply a method to handle the missing values

# %%
NewDF=df.fillna(0)
NewDF
# Out:
#              ID                   country age_group        travel_with  \
# 0        tour_0                SWIZERLAND     45-64  Friends/Relatives
# 1       tour_10            UNITED KINGDOM     25-44                  0
# 2     tour_1000            UNITED KINGDOM     25-44              Alone
# 3     tour_1002            UNITED KINGDOM     25-44             Spouse
# 4     tour_1004                     CHINA      1-24                  0
# ...         ...                       ...       ...                ...
# 4804   tour_993                       UAE     45-64              Alone
# 4805   tour_994  UNITED STATES OF AMERICA     25-44             Spouse
# 4806   tour_995               NETHERLANDS      1-24                  0
# 4807   tour_997              SOUTH AFRICA     25-44  Friends/Relatives
# 4808   tour_999            UNITED KINGDOM     25-44             Spouse
#
#       total_female  total_male                         purpose  \
# ...

# %% [markdown]
# .Check for duplicates and remove if any.

# %%
NewDF.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4804    False
# 4805    False
# 4806    False
# 4807    False
# 4808    False
# Length: 4809, dtype: bool

# %%
#to remove duplicates
#we don't have duplicates so we have nothing to remove but i just wanted to know how to remove duplicates in case we have them
DFND=NewDF.drop_duplicates() # i have to save the changes on a new variable DFND to get a cleaned dataFrame or NewDF will not change if we simply affected the function on it without saving it in a new variable and we need the clean DataFrame to ensure the data cleaning and preprocessing
DFND
# Out:
#              ID                   country age_group        travel_with  \
# 0        tour_0                SWIZERLAND     45-64  Friends/Relatives
# 1       tour_10            UNITED KINGDOM     25-44                  0
# 2     tour_1000            UNITED KINGDOM     25-44              Alone
# 3     tour_1002            UNITED KINGDOM     25-44             Spouse
# 4     tour_1004                     CHINA      1-24                  0
# ...         ...                       ...       ...                ...
# 4804   tour_993                       UAE     45-64              Alone
# 4805   tour_994  UNITED STATES OF AMERICA     25-44             Spouse
# 4806   tour_995               NETHERLANDS      1-24                  0
# 4807   tour_997              SOUTH AFRICA     25-44  Friends/Relatives
# 4808   tour_999            UNITED KINGDOM     25-44             Spouse
#
#       total_female  total_male                         purpose  \
# ...

# %% [markdown]
# Identifying and removing irrelevant columns

# %%
#all of the dataframe columns are relevangt

# %% [markdown]
# DataExploration

# %%
#DFND.mode()
DFND.mode().iloc[0]#The mode is the value that appears most frequently in each column .
# Out:
# ID                                             tour_0
# country                      UNITED STATES OF AMERICA
# age_group                                       25-44
# travel_with                                     Alone
# total_female                                      1.0
# total_male                                        1.0
# purpose                          Leisure and Holidays
# main_activity                        Wildlife tourism
# info_source              Travel, agent, tour operator
# tour_arrangement                          Independent
# package_transport_int                              No
# package_accomodation                               No
# package_food                                       No
# package_transport_tz                               No
# package_sightseeing                                No
# package_guided_tour                                No
# package_insurance                                  No
# ...

# %%
DFND.describe()
# Out:
#        total_female   total_male  night_mainland  night_zanzibar    total_cost
# count   4809.000000  4809.000000     4809.000000     4809.000000  4.809000e+03
# mean       0.926180     1.008526        8.488043        2.304429  8.114389e+06
# std        1.288048     1.138738       10.427624        4.227080  1.222490e+07
# min        0.000000     0.000000        0.000000        0.000000  4.900000e+04
# 25%        0.000000     1.000000        3.000000        0.000000  8.121750e+05
# 50%        1.000000     1.000000        6.000000        0.000000  3.397875e+06
# 75%        1.000000     1.000000       11.000000        4.000000  9.945000e+06
# max       49.000000    44.000000      145.000000       61.000000  9.953288e+07

# %%
#import numpy as np
#numpy return an array without the name of columns so it's clearer to work with the pandas correlation function
# x=np.corrcoef([DFND['total_female'], DFND['total_male'],DFND['night_mainland'],DFND['night_zanzibar'],DFND['total_cost']])
# x

# %%
#we must take only the columns with numerical values
corre_df=DFND[ ['total_female', 'total_male', 'night_mainland', 'night_zanzibar', 'total_cost']].corr()
corre_df
# Out:
#                 total_female  total_male  night_mainland  night_zanzibar  \
# total_female        1.000000    0.463977        0.031114        0.138325
# total_male          0.463977    1.000000       -0.041968        0.050706
# night_mainland      0.031114   -0.041968        1.000000       -0.118155
# night_zanzibar      0.138325    0.050706       -0.118155        1.000000
# total_cost          0.286205    0.182766        0.020473        0.145139
#
#                 total_cost
# total_female      0.286205
# total_male        0.182766
# night_mainland    0.020473
# night_zanzibar    0.145139
# total_cost        1.000000

# %% [markdown]
# Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(corre_df, annot=True,cmap='Blues')
plt.show()

# %% [markdown]
# Find the 3 most frequent countries that visitors tend to come from.

# %%
#Return a Series containing counts of unique values. The resulting object will be in descending order so that the first element is the most frequently-occurring element.
DFND['country'].value_counts()[:3]
# Out:
# country
# UNITED STATES OF AMERICA    695
# UNITED KINGDOM              533
# ITALY                       393
# Name: count, dtype: int64

# %% [markdown]
# Determine the most common purpose of the visit by 'age_group'.

# %%
DFND.groupby('age_group')['purpose']. value_counts()[:1]
# Out:
# age_group  purpose
# 1-24       Leisure and Holidays    349
# Name: count, dtype: int64

# %%
DFND.groupby('age_group')['purpose'].apply(max)
# Out:
# <ipython-input-93-1737688397>:1: FutureWarning: The provided callable <built-in function max> is currently using np.maximum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.maximum.reduce instead.
#   DFND.groupby('age_group')['purpose'].apply(max)
# age_group
# 1-24     Volunteering
# 25-44    Volunteering
# 45-64    Volunteering
# 65+      Volunteering
# Name: purpose, dtype: object

# %%
DFND.groupby("age_group")["purpose"].apply(lambda x:x.mode()[0])#the most correct one
# Out:
# age_group
# 1-24     Leisure and Holidays
# 25-44    Leisure and Holidays
# 45-64    Leisure and Holidays
# 65+      Leisure and Holidays
# Name: purpose, dtype: object

# %% [markdown]
# .Analyse the data distribution of 'total_cost' column with respect to sevreal criteria : Country, age_group, purpose

# %%
DFND.groupby(["country","age_group","purpose"])["total_cost"].describe()
# Out:
#                                                     count          mean  \
# country   age_group purpose
# ALGERIA   25-44     Leisure and Holidays              1.0  3.734348e+06
#                     Visiting Friends and Relatives    1.0  8.287500e+05
# ANGOLA    45-64     Leisure and Holidays              1.0  5.000000e+05
# ARGENTINA 45-64     Leisure and Holidays              1.0  1.044225e+07
# AUSTRALIA 1-24      Leisure and Holidays             10.0  1.242723e+07
# ...                                                   ...           ...
# ZIMBABWE  45-64     Leisure and Holidays              7.0  3.008209e+06
#                     Meetings and Conference           1.0  1.491750e+06
#                     Other                            10.0  6.199062e+05
#                     Visiting Friends and Relatives    4.0  1.995000e+05
#           65+       Business                          1.0  1.000000e+05
#
# ...
